# %%
import pandas as pd

# %%
hospitaldata = pd.read_csv('Hospital_General_Information.csv', encoding="ISO-8859-1")
hospitaldata
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Provider ID</th>
#       <th>Hospital Name</th>
#       <th>Address</th>
#       <th>City</th>
#       <th>State</th>
#       <th>ZIP Code</th>
#       <th>County Name</th>
#       <th>Phone Number</th>
#       <th>Hospital Type</th>
#       <th>Hospital Ownership</th>
#       <th>...</th>
#       <th>Readmission national comparison</th>
#       <th>Readmission national comparison footnote</th>
#       <th>Patient experience national comparison</th>
#       <th>Patient experience national comparison footnote</th>
#       <th>Effectiveness of care national comparison</th>
# ...

# %%
hospitaldata.isnull()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Provider ID</th>
#       <th>Hospital Name</th>
#       <th>Address</th>
#       <th>City</th>
#       <th>State</th>
#       <th>ZIP Code</th>
#       <th>County Name</th>
#       <th>Phone Number</th>
#       <th>Hospital Type</th>
#       <th>Hospital Ownership</th>
#       <th>...</th>
#       <th>Readmission national comparison</th>
#       <th>Readmission national comparison footnote</th>
#       <th>Patient experience national comparison</th>
#       <th>Patient experience national comparison footnote</th>
#       <th>Effectiveness of care national comparison</th>
# ...

# %%
hospitaldata.isnull().sum()
# Out:
# Provider ID                                                         0
# Hospital Name                                                       0
# Address                                                             0
# City                                                                0
# State                                                               0
# ZIP Code                                                            0
# County Name                                                        15
# Phone Number                                                        0
# Hospital Type                                                       0
# Hospital Ownership                                                  0
# Emergency Services                                                  0
# Meets criteria for meaningful use of EHRs                         143
# Hospital overall rating                                             0
# ...

# %%
hospitaldata.notnull()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Provider ID</th>
#       <th>Hospital Name</th>
#       <th>Address</th>
#       <th>City</th>
#       <th>State</th>
#       <th>ZIP Code</th>
#       <th>County Name</th>
#       <th>Phone Number</th>
#       <th>Hospital Type</th>
#       <th>Hospital Ownership</th>
#       <th>...</th>
#       <th>Readmission national comparison</th>
#       <th>Readmission national comparison footnote</th>
#       <th>Patient experience national comparison</th>
#       <th>Patient experience national comparison footnote</th>
#       <th>Effectiveness of care national comparison</th>
# ...

# %%
hospitaldata2=hospitaldata.groupby(['Hospital Ownership','Hospital Type']).size()
hospitaldata2
# Out:
# Hospital Ownership                           Hospital Type
# Government - Federal                         Acute Care Hospitals           37
#                                              Critical Access Hospitals       8
# Government - Hospital District or Authority  Acute Care Hospitals          273
#                                              Childrens                       1
#                                              Critical Access Hospitals     287
# Government - Local                           Acute Care Hospitals          176
#                                              Critical Access Hospitals     231
# Government - State                           Acute Care Hospitals           50
#                                              Childrens                       3
#                                              Critical Access Hospitals      12
# Physician                                    Acute Care Hospitals           65
# ...

# %%
hospitaldata3 = hospitaldata.groupby(['State']).size()
hospitaldata3
# Out:
# State
# AK     22
# AL     90
# AR     75
# AS      1
# AZ     80
# CA    343
# CO     78
# CT     31
# DC      8
# DE      7
# FL    187
# GA    133
# GU      2
# HI     23
# IA    116
# ID     41
# IL    180
# IN    120
# KS    137
# KY     94
# LA    121
# MA     64
# MD     49
# ME     33
# MI    131
# MN    131
# MO    112
# MP      1
# MS     95
# MT     62
# NC    107
# ND     44
# NE     89
# NH     26
# NJ     66
# NM     41
# NV     35
# NY    171
# OH    168
# OK    124
# OR     60
# PA    171
# PR     52
# RI     11
# SC     60
# SD     60
# TN    107
# TX    411
# UT     46
# VA     86
# VI      2
# VT     14
# WA     91
# WI    126
# WV     49
# WY     28
# dtype: int64

# %%
hospitaldata4 = hospitaldata[hospitaldata['State'] == 'TX']
hospitaldata4
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Provider ID</th>
#       <th>Hospital Name</th>
#       <th>Address</th>
#       <th>City</th>
#       <th>State</th>
#       <th>ZIP Code</th>
#       <th>County Name</th>
#       <th>Phone Number</th>
#       <th>Hospital Type</th>
#       <th>Hospital Ownership</th>
#       <th>...</th>
#       <th>Readmission national comparison</th>
#       <th>Readmission national comparison footnote</th>
#       <th>Patient experience national comparison</th>
#       <th>Patient experience national comparison footnote</th>
#       <th>Effectiveness of care national comparison</th>
# ...

# %%
hospitaldata5n=hospitaldata[['State','Hospital Ownership']]
hospitaldata5=hospitaldata5n[hospitaldata['State']=='TX']
hospitaldata5
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>State</th>
#       <th>Hospital Ownership</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3954</th>
#       <td>TX</td>
#       <td>Proprietary</td>
#     </tr>
#     <tr>
#       <th>3955</th>
#       <td>TX</td>
#       <td>Voluntary non-profit - Private</td>
#     </tr>
#     <tr>
#       <th>3956</th>
#       <td>TX</td>
#       <td>Voluntary non-profit - Private</td>
#     </tr>
#     <tr>
#       <th>3957</th>
#       <td>TX</td>
#       <td>Voluntary non-profit - Private</td>
#     </tr>
#     <tr>
#       <th>3958</th>
#       <td>TX</td>
# ...

# %%
hospitaldata6=pd.crosstab(hospitaldata["Hospital Name"],hospitaldata['Timeliness of care national comparison footnote']=='Above the national average')
hospitaldata6
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Timeliness of care national comparison footnote</th>
#       <th>False</th>
#     </tr>
#     <tr>
#       <th>Hospital Name</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>ABBEVILLE AREA MEDICAL CENTER</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ABBEVILLE GENERAL HOSPITAL</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ABBOTT NORTHWESTERN HOSPITAL</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ABILENE REGIONAL MEDICAL CENTER</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ABINGTON MEMORIAL HOSPITAL</th>
#       <td>1</td>
#     </tr>
#     <tr>
# ...

# %%
hospital_ratings =  hospitaldata[['Hospital Name','Hospital overall rating']]
hospital_ratings
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Hospital Name</th>
#       <th>Hospital overall rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>SOUTHEAST ALABAMA MEDICAL CENTER</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>MARSHALL MEDICAL CENTER SOUTH</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ELIZA COFFEE MEMORIAL HOSPITAL</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>MIZELL MEMORIAL HOSPITAL</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>CRENSHAW COMMUNITY HOSPITAL</td>
# ...

# %%
hospitaldata8=hospitaldata.loc[(hospitaldata["Hospital Type"]=="Acute Care Hospitals")&(hospitaldata["Hospital overall rating"]=="4"),["Hospital Name","State"]]
hospitaldata8
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Hospital Name</th>
#       <th>State</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>10</th>
#       <td>DALE MEDICAL CENTER</td>
#       <td>AL</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>CHEROKEE MEDICAL CENTER</td>
#       <td>AL</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>EAST ALABAMA MEDICAL CENTER</td>
#       <td>AL</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>WEDOWEE HOSPITAL</td>
#       <td>AL</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>COMMUNITY HOSPITAL INC</td>
#       <td>AL</td>
#     </tr>
#     <tr>
# ...

# %%
hospitaldata9n = hospitaldata[hospitaldata['Safety of care national comparison']=='Not Available']
hospitaldata9 = hospitaldata9n.groupby('Hospital Type').size()
hospitaldata9
# Out:
# Hospital Type
# Acute Care Hospitals          727
# Childrens                      99
# Critical Access Hospitals    1342
# dtype: int64

# %%
hospitaldata10=hospitaldata.loc[:,['Provider ID','Patient experience national comparison']]
hospitaldata10
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Provider ID</th>
#       <th>Patient experience national comparison</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10001</td>
#       <td>Below the national average</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10005</td>
#       <td>Same as the national average</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>10006</td>
#       <td>Below the national average</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>10007</td>
#       <td>Same as the national average</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>10008</td>
# ...
